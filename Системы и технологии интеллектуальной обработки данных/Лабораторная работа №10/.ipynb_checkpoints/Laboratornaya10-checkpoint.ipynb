# %%
import cv2
import argparse
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("Image.jpg", 1)
print(image.shape)
# Out:
# (1280, 851, 3)

# %%
cv2.imshow('Image', image)
k = cv2.waitKey(0)
if k == 27 or k == ord('q'):
    cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite('Image.jpg', gray)
# Out:
# True

# %%
cv2.imshow('Image', gray)
k = cv2.waitKey(0)
if k == 27 or k == ord('q'):
    cv2.destroyAllWindows()

# %%
#	бинарное изображение (черно-белое), полученное при помощи функции пороговой бинаризации threshold
img = cv2.imread('Image.jpg',0)
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
# среднее значение площади окрестности минус константа C
# пороговое значение представляет собой взвешенную по Гауссу сумму значений окрестности минус константа C
#  C — константа, которая вычитается из средней или взвешенной суммы пикселей соседства
#	бинарное изображение, полученное при помощи функции адаптивной бинаризации 
img = cv2.imread('Image.jpg',0)
img = cv2.medianBlur(img,5)

ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
#Выровняйте освещенность изображения при помощи функции equalizeHist

image = cv2.imread("Image_Black.jpg", 1)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imwrite('Image_Black.jpg', gray)

dst = cv2.equalizeHist(gray) # Контрастность 
cv2.imshow('Source image', gray)
cv2.imshow('Equalized Image', dst)
cv2.waitKey()
# Out:
# -1

# %%
plt.hist(gray.ravel(), 256, [0,256])
plt.show()

# %%
plt.hist(dst.ravel(), 256, [0,256])
plt.show()

# %%
#Image blur - 
image2 = cv2.imread('Image2.jpg')
blur = cv2.blur(image2,(5,8))
plt.subplot(121),plt.imshow(image2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
cv2.imshow('Image', image2)
cv2.waitKey()
# Out:
# -1

# %%
cv2.imshow('Image', blur)
cv2.waitKey()
# Out:
# -1

# %%
#Для нормализации по координатам введена сигма (среднеквадратическое отклонение), которая определяет
#степень сжатия гауссианы
blur = cv2.GaussianBlur(image2,(5,5),0)

plt.subplot(121),plt.imshow(image2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
cv2.imshow('Image', image2)
cv2.waitKey()
# Out:
# -1

# %%
cv2.imshow('Image', blur)
cv2.waitKey()
# Out:
# -1

# %%
#Фильтр работает с матрицами различного размера, но в отличие от матрицы свёртки, размер
#матрицы влияет только на количество рассматриваемых пикселей.
median = cv2.medianBlur(image2,7)

plt.subplot(121),plt.imshow(image2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
cv2.imshow('Image', image2)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow('Image', median)
cv2.waitKey()
# Out:
# -1

# %%
# Reading the input image
img = cv2.imread('off.jpg', 0)
 
# Taking a matrix of size 5 as the kernel
kernel = np.ones((5, 5), np.uint8)
 
# The first parameter is the original image,
# kernel is the matrix with which image is
# convolved and third parameter is the number
# of iterations, which will determine how much
# you want to erode/dilate a given image.

#операции эрозии; Он возвращает размытое изображение.
img_erosion = cv2.erode(img, kernel, iterations=1)

#Расширение увеличивает белую область на изображении или размер объекта переднего плана
img_dilation = cv2.dilate(img, kernel, iterations=1)
 
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_erosion),plt.title('erode')
plt.xticks([]), plt.yticks([])
plt.show() 
plt.subplot(122),plt.imshow(img_dilation),plt.title('dilate')
plt.xticks([]), plt.yticks([])
plt.show()    
    
cv2.imshow('Input', img)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow('Erosion', img_erosion)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow('Dilation', img_dilation)
cv2.waitKey(0)
# Out:
# -1
